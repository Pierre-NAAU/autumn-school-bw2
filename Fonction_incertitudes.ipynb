# %%
import pandas as pd

# %%
df=pd.read_excel("lci-concrete-with-uncertainties.xlsx")

# %%
df
# Out:
#                                              Database  concrete us  \
# 0                                                 NaN          NaN
# 1                                            Activity          NaN
# 2                                            location          RER
# 3                                   production amount            1
# 4                                   reference product  concrete us
# 5                                                type      process
# 6                                                unit     kilogram
# 7                                           Exchanges          NaN
# 8                                                name       amount
# 9                                         concrete us            1
# 10             market for cement, all types, adjusted          290
# 11               concrete mixing factory construction          0.0
# 12      market for diesel, burned in building machine          0.4
# ...

# %%
def function(activity_name):
    dict_ex={}
    if list(df)[1]==activity_name:
        for i in range (10,len(df)):
            name_ex=df['Database'][i]
            dict_ex[name_ex]=df['Unnamed: 10'][i]
    return (dict_ex)

# %%
function('concrete us')
# Out:
# {'market for cement, all types, adjusted': 0.118,
#  'concrete mixing factory construction': 0.566,
#  'market for diesel, burned in building machine': 0.103,
#  'market for electricity, medum voltage': 0.103,
#  'market for gravel, round': 0.134,
#  'market for heat, district or industrial, natural gas': 0.155,
#  'heat production, light fuel oil, at industrial furnace 1MW': 0.155,
#  'market for lubricating oil': 0.103,
#  'market for municipal solid waste': 0.103,
#  'market for sand': 0.214,
#  'market for synthetic rubber': 0.103,
#  'market for tap water': 0.113,
#  'market for waste concrete': 0.103}
