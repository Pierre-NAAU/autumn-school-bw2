# %% [markdown]
# -----------------RCC-crushed-------------------------
#
# Line=3
# AnnualProd = 20000 #☻kg/year annual production
# NbWeek = 3 #week/year number of weeks with mobile crusher
# R = 1.35
# TimeRatio = NbWeek/54 #time of crushing in the total working annual time
# IR = TimeRatio /AnnualProd
#
# D_exchanges_RCC={
#     "input name": ['market for diesel, burned in building machine',
#                    'market for electricity, medium voltage',
#                    'market for gravel/sand quarry infrastructure',
#                    'market for heat, central or small-scale, other than natural gas',
#                    'market for lubricating oil',
#                    'market for steel, low-alloyed, hot rolled',
#                    'market for synthetic rubber',
#                    'market for tap water'
#                    ]
#     ,"input location" : ['GLO',
#                          'FR',
#                          'GLO',
#                          'Europe without Switzerland',
#                          'RER',
#                          'GLO',
#                          'GLO',
#                          'Europe without Switzerland'
#
#                          ]
#     ,"amount" : [0.0143/Line ,
#                  0.00906/Line ,
#                  4.75E-11/Line *IR,
#                  0.00491/Line ,
#                  2.5E-6/Line ,
#                  5.1E-5/Line ,
#                  4.0E-6/Line ,
#                  1.0/Line ,
#
#                  ]
#     ,"unit" :["megajoule",
#               "kilowatt hour",
#               "unit",
#               "megajoule",
#               "kilogram",
#               "kilogram",
#               "kilogram",
#               "kilogram",
#               ]
#     ,"type":["technosphere",
#              "technosphere",
#              "technosphere",
#              "technosphere",
#              "technosphere",
#              'technosphere',
#              'technosphere',
#              'technosphere']
#     }
#
#
# """
# --------------DC-concrete------------
#
# Concrete CEMII based on INIES 11081
# https://www.base-inies.fr/iniesV4/dist/consultation.html?id=11081
#
#
# """
# d_A4 = 18.5 #distance transport au site
# d_C2_land = 30 #Distance pour élimination déchets
# d_C2_recycle = 30 #Distance pour recyclage
# p_concrete = 2400 #masse volumique béton
# per_landfill = 0.25 #Pourcentage enfouissement
# per_recycled = 0.75 #Pourcentage recyclé
#
# D_exchanges_DC_concrete={
#     "input name": ['concrete production, for building construction, with cement CEM II/A',
#                    'electricity, high voltage, production mix',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'treatment of waste concrete, inert material landfill',
#                    'RCC, crushed, operation']
#     ,"input location" : ['CH',
#                          'FR',
#                          'RER',
#                          'RER',
#                          'RER',
#                          'Europe without Switzerland',
#                          'FR']
#     ,"amount" : [1.03, #03 pour 3% de perte
#                  385.2/3.6, #A5 installation
#                  p_concrete*d_A4/1000, #A4
#                  p_concrete*d_C2_land *per_landfill/1000, #C2
#                  p_concrete*d_C2_recycle *per_recycled/1000, #C2
#                  -1*per_landfill *p_concrete,
#                  per_recycled*p_concrete]
#     ,"unit" :["cubic meter",
#               "kilowatt hour",
#               "ton kilometer",
#               "ton kilometer",
#               'ton kilometer',
#               'kilogram',
#               'kilogram']
#     ,"type":["technosphere",
#              "technosphere",
#              "technosphere",
#              "technosphere",
#              "technosphere",
#              'technosphere',
#              'technosphere']
#     }
#
#
#
# """
# -------DC-reinforcing steel----------
#
# Production based on DIOGEN
#
# End of life based on INIES 9055
# https://www.base-inies.fr/iniesV4/dist/consultation.html?id=9055
#
# """
# d_A4 = 270 #distance transport au site
# d_C2_land = 50 #Distance pour élimination déchets
# d_C2_recycle = 250 #Distance pour recyclage
# d_C2_reuse = 250 #Distance au centre de valorisation
# per_landfill = 0.02 #Pourcentage enfouissement
# per_recycled = 0.87 #Pourcentage recyclé
# per_reuse = 0.11 #Pourcentage réutilisé
#
#
# D_exchanges_DC_reinforcing_steel={
#     "input name": ['Reinforcing steel, Diogen',#diesel for machine for installation/deconstruction taken in account in BB-concrete
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'treatment of scrap steel, inert material landfill']
#     ,"input location" : ['FR',
#                          'RER',
#                          'RER',
#                          'RER',
#                          'RER',
#                          'CH']
#     ,"amount" : [1,
#                  d_A4 /1000, #A4
#                  d_C2_reuse *per_reuse /1000, #C2
#                  d_C2_recycle *per_recycled  /1000, #C2
#                  d_C2_land *per_landfill  /1000, #C2
#                  -1*per_landfill]
#     ,"unit" :["kilogram",
#               "ton kilometer",
#               'ton kilometer',
#               'ton kilometer',
#               'ton kilometer',
#               'kilogram']
#     ,"type":["technosphere",
#              "technosphere",
#              "technosphere",
#              'technosphere',
#              "technosphere",
#              "technosphere"]
#     }
#
#
# """
# -------SP-steel----------
#
# Steel based on INIES 9055
# https://www.base-inies.fr/iniesV4/dist/consultation.html?id=9055
#
# """
# d_A4 = 270 #distance transport au site
# d_C2_land = 50 #Distance pour élimination déchets
# d_C2_recycle = 250 #Distance pour recyclage
# d_C2_reuse = 250 #Distance au centre de valorisation
# per_landfill = 0.02 #Pourcentage enfouissement
# per_recycled = 0.87 #Pourcentage recyclé
# per_reuse = 0.11 #Pourcentage réutilisé
#
#
# D_exchanges_SP_steel={
#     "input name": ['market for steel, low-alloyed, hot rolled',
#                    'diesel, burned in building machine',
#                    'diesel, burned in building machine',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'transport, freight, lorry 16-32 metric ton, EURO6',
#                    'treatment of scrap steel, inert material landfill']
#     ,"input location" : ['GLO',
#                          'GLO',
#                          'GLO',
#                          'RER',
#                          'RER',
#                          'RER',
#                          'RER',
#                          'CH']
#     ,"amount" : [1.05, #Comprend les chutes
#                  0.0054*p_diesel*LHV_diesel, #A5
#                  0.0054*p_diesel*LHV_diesel, #C1
#                  d_A4 /1000, #A4
#                  d_C2_reuse *per_reuse /1000, #C2
#                  d_C2_recycle *per_recycled  /1000, #C2
#                  d_C2_land *per_landfill  /1000, #C2
#                  -1*per_landfill]
#     ,"unit" :["kilogram",
#               "megajoule",
#               "megajoule",
#               "ton kilometer",
#               'ton kilometer',
#               'ton kilometer',
#               'ton kilometer',
#               'kilogram']
#     ,"type":["technosphere",
#              "technosphere",
#              "technosphere",
#              'technosphere',
#              "technosphere",
#              "technosphere",
#              "technosphere",
#              "technosphere"]
#     }
